# %%
###crt day 5
###29/05/2026
import numpy as np
import pandas as pd
df=pd.DataFrame({
    "name":["swathi","lakshmi","nandini","lohitha","vyshnavi","nageswari","reddy","sunny","bunny","yashwanth"],
    "age":[20,22,32,21,27,26,29,26,25,28],
    "experience":[2,3,4,5,3,2,1,4,5,6],
    "finanace":[80000,30000,40000,50000,60000,20000,19000,50000,70000,38000],
    "city":["tirupati","kadapa","renigunta","kodur","rajampeta","chitoor","madanapalli","tanapalli","karkambadi","settigunta"]
})
df.isna()#is not available ,it means where the data set is not available there it will show false and the rest are true
df.isnull()#same as df.isna()
df.isna().sum()#shows no of missing values in each column of data
df.notna().sum()#shows no of values in each column exept null values
df.notnull()#same as df.notna()
df.notnull().sum()#same as df.notna().sum()

# %%
###crt day 5
###29/05/2026
import numpy as np
import pandas as pd
df=pd.DataFrame({
    "name":["swathi","lakshmi","nandini","lohitha","vyshnavi","nageswari","reddy","sunny","bunny","yashwanth"],
    "age":[20,22,32,21,27,26,29,26,25,28],
    "experience":[2,3,4,5,3,2,1,4,5,6],
    "finanace":[80000,30000,40000,50000,60000,20000,19000,50000,70000,38000],
    "city":["tirupati","kadapa","renigunta","kodur","rajampeta","chitoor","madanapalli","tanapalli","karkambadi","settigunta"]
})
len(df)
df.isna().sum()/len(df)*100   #percentage of nulldata
df.isna().mean()*100   #percentage of nulldata
df.notnull().sum()/len(df)*100   #percentage of not nulldata
df.notnull().mean()*100   #percentage of not nulldata
df[df.isna().any(axis=1)]#it will return the rows which have at least one missing value in any column
df[df.isna().all(axis=1)]#it will return the rows which have all null values
df[df["name"].isna()]
