# %% [markdown]
# What is Data Analytics?
# using historical data to analysis diffrent models to make proper decisions

# %%
marks=[27,45,43,35,38]
summ=sum(marks)
avg=summ/5
print(summ)
print(avg)

# %%
*the cell contain student data about marks
*marks sum and average
